# %%
import os
import spacy
import json
import csv
import re
import logging
from pyresparser import ResumeParser
from pdfminer.high_level import extract_text  # To extract text from PDF files
from tqdm import tqdm  # For progress tracking

# Setup logging
logging.basicConfig(filename='resume_extraction.log', level=logging.ERROR, 
                    format='%(asctime)s %(levelname)s: %(message)s')

# Load the SpaCy model
nlp = spacy.load("en_core_web_sm")

# Generalized function to extract names using SpaCy NER, regex, and comparison with ResumeParser
import re
import spacy

# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

def extract_name_general(resume_text, resume_parser_name=None):
    doc = nlp(resume_text)
    
    # Use SpaCy to detect PERSON entities
    person_names = [ent.text for ent in doc.ents if ent.label_ == "PERSON"]
    
    # If ResumeParser has extracted a name, compare and use it if found
    if resume_parser_name:
        for name in person_names:
            # If ResumeParser's name matches one of the SpaCy-detected names, return it
            if resume_parser_name.lower() in name.lower():
                return name

    # Regex pattern to extract names: First Name, Optional Middle Name, Last Name
    name_pattern = re.compile(r'\b([A-Z][a-z]+(?:\s+[A-Z][a-z]+)*\s+[A-Z][a-z]+(?:[-\s][A-Z][a-z]+)*)\b')
    name_match = name_pattern.search(resume_text)
    if name_match:
        return name_match.group(0)
    
    # Fallback to the first line of the resume (assuming the name might be at the top)
    first_line = resume_text.split('\n')[0].strip()
    
    # Check if the first line matches the name format (First Last or First Middle Last)
    fallback_name_match = name_pattern.search(first_line)
    if fallback_name_match:
        return fallback_name_match.group(0)

    # If no names were found, return None or a suitable message
    return None


# Load SpaCy model
nlp = spacy.load("en_core_web_sm")

def extract_company_names(resume_text):
    company_names = []
    company_keywords = [
        'Inc', 'Corp', 'Ltd', 'Technologies', 'Systems', 'Solutions', 'LLC', 'Pvt', 'Private Limited', 
        'Limited', 'Labs', 'Consulting', 'Group', 'Partners', 'Industries', 'Services', 'Networks'
    ]
    
    # Use SpaCy to detect organizations
    doc = nlp(resume_text)
    for ent in doc.ents:
        if ent.label_ == "ORG" and len(ent.text) > 2:
            company_names.append(ent.text.strip())

    # Regex pattern to detect company names with common suffixes
    company_pattern = re.compile(
        r'\b([A-Z][a-zA-Z]+(?:\s+[A-Z][a-zA-Z]+)*\s+(Inc|Corp|Ltd|LLC|Pvt|Technologies|Solutions|Systems|Private Limited|Limited|Labs|Consulting|Group|Partners|Industries|Services|Networks))\b'
    )
    company_matches = company_pattern.findall(resume_text)
    if company_matches:
        company_names.extend([match[0].strip() for match in company_matches])

    # Additional context-based pattern for identifying lines with company-related keywords
    for line in resume_text.split('\n'):
        if any(keyword in line for keyword in company_keywords):
            company_names.append(line.strip())

    # Post-processing to filter out irrelevant terms (like job titles, skills, or unrelated terms)
    irrelevant_terms = [
        'Engineer', 'QA', 'SQL', 'Developer', 'Tester', 'Testing', 'Data', 'Planning', 
        'Consultant', 'Security', 'Audit', 'Manager', 'Analysis', 'System', 'Service', 'Methods', 'Owner', 'Demo'
    ]

    # Remove company names containing irrelevant terms
    filtered_company_names = [name for name in company_names if not any(term in name for term in irrelevant_terms)]
    
    # Final filter for ensuring the remaining names have company keywords or reasonable length
    final_filtered_company_names = [
        name for name in filtered_company_names
        if any(keyword in name for keyword in company_keywords) or len(name.split()) > 1
    ]

    # Return the cleaned list of company names, ensuring no duplicates
    return list(set(final_filtered_company_names))


# Generalized function to extract college names using regex and keyword-based patterns
def extract_college_names(resume_text):
    college_keywords = ['University', 'Institute', 'College', 'Academy', 'School of', 'Faculty of']
    college_names = []

    # Regex pattern for college names
    college_pattern = re.compile(r'[A-Z][a-zA-Z]+\s+(University|Institute|College|Academy|School|Faculty of)')
    college_matches = college_pattern.findall(resume_text)
    college_names.extend(college_matches)

    # Keyword-based pattern
    for line in resume_text.split('\n'):
        if any(keyword in line for keyword in college_keywords):
            college_names.append(line.strip())

    return list(set(college_names))

# Generalized function to extract total experience using regex
def extract_total_experience(resume_text):
    # Pattern matching for 'X years Y months'
    experience_pattern = re.compile(r'(\d+\s*years?\s*\d*\s*months?)')
    match = experience_pattern.search(resume_text)
    if match:
        return match.group(0)

    # Additional pattern for 'X+ years'
    experience_pattern_plus = re.compile(r'(\d+)\+?\s*(years?|months?)')
    match_plus = experience_pattern_plus.search(resume_text)
    if match_plus:
        return match_plus.group(0)

    return "Experience not specified"

# Function to extract text from a PDF file
def extract_resume_text(file_path):
    try:
        return extract_text(file_path)
    except Exception as e:
        logging.error(f"Failed to extract text from {file_path}: {e}")
        return ""

# Specify the folder path with resume PDF files
folder_path = r"C:\Users\91901\OneDrive\Desktop\resumes"  # Change this to your actual folder path

# List to hold the extracted data from all resumes
extracted_data = []

# Progress bar for batch processing
resume_files = [f for f in os.listdir(folder_path) if f.endswith(".pdf")]

# Iterate through all the files in the folder
for filename in tqdm(resume_files, desc="Processing resumes"):
    resume_path = os.path.join(folder_path, filename)
    
    try:
        # Parse the resume using pyresparser
        data = ResumeParser(resume_path).get_extracted_data()

        # Extract text from the PDF for custom extraction
        resume_text = extract_resume_text(resume_path)
        
        # Generalized name extraction (now with comparison to ResumeParser result)
        extracted_name = extract_name_general(resume_text, data.get('name'))
        if extracted_name:
            data['name'] = extracted_name  # Override the name field with more accurate name
        
        # Generalized company names extraction
        company_names = extract_company_names(resume_text)
        if company_names:
            data['company_names'] = company_names
        
        # Generalized total experience extraction
        total_experience = extract_total_experience(resume_text)
        if total_experience:
            data['total_experience'] = total_experience
        
        # Generalized college extraction
        extracted_colleges = extract_college_names(resume_text)
        if extracted_colleges:
            data['college_name'] = extracted_colleges

        # Append the extracted data along with filename for reference
        if data:
            data['file_name'] = filename
            extracted_data.append(data)

    except Exception as e:
        logging.error(f"An error occurred while processing {filename}: {e}")

# Save the extracted data to a JSON file (replace with a valid path on your system)
json_output_path = r"C:\Users\91901\OneDrive\Desktop\Saved.json"  # Change this to a valid output path
with open(json_output_path, 'w', encoding='utf-8') as json_file:
    json.dump(extracted_data, json_file, ensure_ascii=False, indent=4)

# Save the extracted data to a CSV file (replace with a valid path on your system)
if extracted_data:  # Only save if we have data
    csv_output_path = r"C:\Users\91901\OneDrive\Desktop\Saved.csv"  # Change this to a valid output path
    csv_columns = extracted_data[0].keys()  # Get the keys from the first dict as column headers
    
    with open(csv_output_path, 'w', newline='', encoding='utf-8') as csv_file:
        writer = csv.DictWriter(csv_file, fieldnames=csv_columns)
        writer.writeheader()
        for data in extracted_data:
            writer.writerow(data)

print(f"Data has been saved to {json_output_path} and {csv_output_path}")
# Out:
# Processing resumes:   0%|                                                                      | 0/115 [00:00<?, ?it/s]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:   1%|▌                                                             | 1/115 [00:01<03:18,  1.74s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:   2%|█                                                             | 2/115 [00:07<08:04,  4.29s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:   3%|█▌                                                            | 3/115 [00:09<05:51,  3.14s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:   3%|██▏                                                           | 4/115 [00:13<06:28,  3.50s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:   4%|██▋                                                           | 5/115 [00:18<07:06,  3.88s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:   5%|███▏                                                          | 6/115 [00:21<06:33,  3.61s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:   6%|███▊                                                          | 7/115 [00:23<05:46,  3.20s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:   7%|████▎                                                         | 8/115 [00:26<05:39,  3.17s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:   8%|████▊                                                         | 9/115 [00:29<05:28,  3.10s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:   9%|█████▎                                                       | 10/115 [00:32<05:25,  3.10s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  10%|█████▊                                                       | 11/115 [00:34<04:48,  2.78s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  10%|██████▎                                                      | 12/115 [00:36<04:17,  2.50s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  11%|██████▉                                                      | 13/115 [00:38<03:58,  2.34s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  12%|███████▍                                                     | 14/115 [00:40<03:50,  2.28s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  13%|███████▉                                                     | 15/115 [00:44<04:25,  2.65s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  14%|████████▍                                                    | 16/115 [00:46<04:16,  2.59s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  15%|█████████                                                    | 17/115 [00:50<04:43,  2.90s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  16%|█████████▌                                                   | 18/115 [00:52<04:12,  2.60s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  17%|██████████                                                   | 19/115 [00:54<03:47,  2.37s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  17%|██████████▌                                                  | 20/115 [00:56<03:34,  2.26s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  18%|███████████▏                                                 | 21/115 [01:05<06:58,  4.45s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  19%|███████████▋                                                 | 22/115 [01:07<05:48,  3.75s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  20%|████████████▏                                                | 23/115 [01:09<04:56,  3.22s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  21%|████████████▋                                                | 24/115 [01:11<04:19,  2.85s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  22%|█████████████▎                                               | 25/115 [01:13<03:58,  2.64s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  23%|█████████████▊                                               | 26/115 [01:16<03:41,  2.48s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  23%|██████████████▎                                              | 27/115 [01:18<03:25,  2.33s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  25%|███████████████▍                                             | 29/115 [01:21<02:57,  2.06s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  26%|███████████████▉                                             | 30/115 [01:28<04:58,  3.51s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  27%|████████████████▍                                            | 31/115 [01:30<04:28,  3.20s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  29%|█████████████████▌                                           | 33/115 [01:43<07:12,  5.28s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  30%|██████████████████                                           | 34/115 [01:44<05:32,  4.11s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  30%|██████████████████▌                                          | 35/115 [01:49<05:48,  4.36s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  31%|███████████████████                                          | 36/115 [01:51<04:32,  3.45s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  32%|███████████████████▋                                         | 37/115 [01:55<04:50,  3.73s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  33%|████████████████████▏                                        | 38/115 [01:57<04:09,  3.24s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  34%|████████████████████▋                                        | 39/115 [02:07<06:24,  5.06s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  35%|█████████████████████▏                                       | 40/115 [02:10<05:33,  4.44s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  36%|█████████████████████▋                                       | 41/115 [02:12<04:46,  3.87s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  37%|██████████████████████▎                                      | 42/115 [02:14<04:02,  3.32s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  37%|██████████████████████▊                                      | 43/115 [02:24<06:26,  5.37s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  38%|███████████████████████▎                                     | 44/115 [02:26<05:13,  4.42s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  39%|███████████████████████▊                                     | 45/115 [02:29<04:29,  3.85s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  40%|████████████████████████▍                                    | 46/115 [02:31<03:56,  3.42s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  41%|████████████████████████▉                                    | 47/115 [02:33<03:11,  2.82s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  42%|█████████████████████████▍                                   | 48/115 [02:35<03:01,  2.72s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  43%|█████████████████████████▉                                   | 49/115 [02:38<02:57,  2.69s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  43%|██████████████████████████▌                                  | 50/115 [02:40<02:46,  2.56s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  44%|███████████████████████████                                  | 51/115 [02:42<02:33,  2.40s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  45%|███████████████████████████▌                                 | 52/115 [02:44<02:11,  2.08s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  46%|████████████████████████████                                 | 53/115 [02:46<02:13,  2.15s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  47%|████████████████████████████▋                                | 54/115 [02:52<03:28,  3.42s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  48%|█████████████████████████████▏                               | 55/115 [02:55<03:21,  3.36s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  49%|█████████████████████████████▋                               | 56/115 [02:58<02:58,  3.02s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  50%|██████████████████████████████▏                              | 57/115 [03:01<02:53,  2.98s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  50%|██████████████████████████████▊                              | 58/115 [03:04<02:56,  3.11s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  51%|███████████████████████████████▎                             | 59/115 [03:06<02:28,  2.65s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  52%|███████████████████████████████▊                             | 60/115 [03:09<02:30,  2.74s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  53%|████████████████████████████████▎                            | 61/115 [03:12<02:40,  2.97s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  54%|████████████████████████████████▉                            | 62/115 [03:16<02:48,  3.18s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  55%|█████████████████████████████████▍                           | 63/115 [03:18<02:24,  2.78s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  56%|█████████████████████████████████▉                           | 64/115 [03:19<02:08,  2.52s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  57%|██████████████████████████████████▍                          | 65/115 [03:21<01:58,  2.38s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  57%|███████████████████████████████████                          | 66/115 [03:24<02:03,  2.52s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  58%|███████████████████████████████████▌                         | 67/115 [03:27<01:58,  2.47s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  59%|████████████████████████████████████                         | 68/115 [03:28<01:42,  2.18s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  60%|████████████████████████████████████▌                        | 69/115 [03:30<01:28,  1.93s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  61%|█████████████████████████████████████▏                       | 70/115 [03:32<01:31,  2.04s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  62%|█████████████████████████████████████▋                       | 71/115 [03:35<01:49,  2.48s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  63%|██████████████████████████████████████▋                      | 73/115 [03:39<01:35,  2.26s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  64%|███████████████████████████████████████▎                     | 74/115 [03:42<01:35,  2.32s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  65%|███████████████████████████████████████▊                     | 75/115 [03:44<01:32,  2.31s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  66%|████████████████████████████████████████▎                    | 76/115 [03:46<01:28,  2.27s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  67%|████████████████████████████████████████▊                    | 77/115 [03:49<01:31,  2.40s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  68%|█████████████████████████████████████████▎                   | 78/115 [03:51<01:27,  2.36s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  69%|█████████████████████████████████████████▉                   | 79/115 [03:54<01:27,  2.43s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  70%|██████████████████████████████████████████▍                  | 80/115 [03:59<01:52,  3.21s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  70%|██████████████████████████████████████████▉                  | 81/115 [04:02<01:44,  3.06s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  71%|███████████████████████████████████████████▍                 | 82/115 [04:03<01:28,  2.67s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  72%|████████████████████████████████████████████                 | 83/115 [04:06<01:22,  2.57s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  73%|████████████████████████████████████████████▌                | 84/115 [04:09<01:25,  2.75s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# ...
#   warnings.warn(warn_msg)
# Processing resumes:  77%|██████████████████████████████████████████████▋              | 88/115 [04:18<01:02,  2.31s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  77%|███████████████████████████████████████████████▏             | 89/115 [04:20<00:57,  2.22s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  78%|███████████████████████████████████████████████▋             | 90/115 [04:23<00:59,  2.40s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  79%|████████████████████████████████████████████████▎            | 91/115 [04:26<01:00,  2.50s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  80%|████████████████████████████████████████████████▊            | 92/115 [04:28<00:56,  2.44s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  81%|█████████████████████████████████████████████████▎           | 93/115 [05:41<08:38, 23.59s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  82%|█████████████████████████████████████████████████▊           | 94/115 [05:48<06:35, 18.82s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  83%|██████████████████████████████████████████████████▍          | 95/115 [05:57<05:12, 15.61s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  83%|██████████████████████████████████████████████████▉          | 96/115 [05:59<03:43, 11.76s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  84%|███████████████████████████████████████████████████▍         | 97/115 [06:02<02:40,  8.94s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  85%|███████████████████████████████████████████████████▉         | 98/115 [06:04<01:56,  6.86s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  86%|████████████████████████████████████████████████████▌        | 99/115 [06:07<01:30,  5.65s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  87%|████████████████████████████████████████████████████▏       | 100/115 [06:10<01:16,  5.12s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  88%|████████████████████████████████████████████████████▋       | 101/115 [06:13<00:59,  4.28s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  89%|█████████████████████████████████████████████████████▏      | 102/115 [06:16<00:50,  3.89s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  90%|█████████████████████████████████████████████████████▋      | 103/115 [06:19<00:42,  3.56s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  90%|██████████████████████████████████████████████████████▎     | 104/115 [06:21<00:36,  3.29s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  91%|██████████████████████████████████████████████████████▊     | 105/115 [06:24<00:31,  3.12s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  92%|███████████████████████████████████████████████████████▎    | 106/115 [06:26<00:26,  2.93s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  93%|███████████████████████████████████████████████████████▊    | 107/115 [06:29<00:22,  2.85s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  94%|████████████████████████████████████████████████████████▎   | 108/115 [06:32<00:19,  2.79s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  95%|████████████████████████████████████████████████████████▊   | 109/115 [06:34<00:15,  2.50s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  96%|█████████████████████████████████████████████████████████▍  | 110/115 [06:35<00:11,  2.31s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  97%|█████████████████████████████████████████████████████████▉  | 111/115 [06:38<00:09,  2.26s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  97%|██████████████████████████████████████████████████████████▍ | 112/115 [06:39<00:06,  2.10s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  98%|██████████████████████████████████████████████████████████▉ | 113/115 [06:41<00:04,  2.00s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes:  99%|███████████████████████████████████████████████████████████▍| 114/115 [06:43<00:01,  1.90s/it]D:\resumeparser\resumeparser-env\lib\site-packages\spacy\util.py:275: UserWarning: [W031] Model 'en_training' (0.0.0) requires spaCy v2.1 and is incompatible with the current spaCy version (2.3.5). This may lead to unexpected results or runtime errors. To resolve this, download a newer compatible model or retrain your custom model with the current spaCy version. For more details and available updates, run: python -m spacy validate
#   warnings.warn(warn_msg)
# Processing resumes: 100%|████████████████████████████████████████████████████████████| 115/115 [06:45<00:00,  3.52s/it]
# Data has been saved to C:\Users\91901\OneDrive\Desktop\Saved.json and C:\Users\91901\OneDrive\Desktop\Saved.csv
